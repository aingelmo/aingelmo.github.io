# %%
import pandas as pd
from sqlalchemy import create_engine
from config.config import conn

# %%
df = pd.read_sql('SELECT * FROM covid_data LIMIT 5', conn)

# %%
df.head()
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      LBY    Africa    Libya  2020-09-17      25822.0      886.0
# 1      LBY    Africa    Libya  2020-09-18      26438.0      616.0
# 2      LBY    Africa    Libya  2020-09-19      27234.0      796.0
# 3      LBY    Africa    Libya  2020-09-20      27949.0      715.0
# 4      LBY    Africa    Libya  2020-09-21      28796.0      847.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0             697.571         409.0        15.0               10.000  ...
# 1             647.143         418.0         9.0                9.429  ...
# 2             698.000         436.0        18.0               11.714  ...
# 3             738.286         444.0         8.0               11.714  ...
# 4             754.429         450.0         6.0               11.714  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0            None          None                    None
# ...
